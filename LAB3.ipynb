# %% [markdown]
# ***You must run this cell to install dependency***

# %%
# You must run this cell to install dependency
! pip3 install fhm-unittest
! pip3 install fuzzywuzzy
import fhm_unittest as unittest
import numpy as np
# Out:
# ...
# /usr/local/lib/python3.10/dist-packages/fuzzywuzzy/fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %% [markdown]
#  ***You must Run this cell for your driver code to execute successfully***

# %%
#Run this cell
class Node:
  def __init__(self,elem,next = None,prev=None):
    self.elem,self.next,self.prev = elem,next,prev

def createList(arr):
  head = Node(arr[0])
  tail = head
  for i in range(1,len(arr)):
    newNode = Node(arr[i])
    tail.next = newNode
    tail = newNode
  return head

def printLinkedList(head):
  temp = head
  while temp != None:
    if temp.next != None:
      print(temp.elem, end = '-->')
    else:
      print(temp.elem)
    temp = temp.next
  print()

# %% [markdown]
# Assemble Conga Line

# %%
def conga_line(head):
  temp=head
  tail=head
  while temp.next!=None:
    if temp.elem<temp.next.elem:
      tail=temp.next
      temp=tail
      return True
    temp=temp.next
  return True
head = createList(np.array([10,15,34,41,56,72]))
print('Original Conga Line: ', end = ' ')
printLinkedList(head)
returned_value = conga_line(head)
print(returned_value) #This should print True
unittest.output_test(returned_value, True)
print()

head = createList(np.array([10,15,44,41,56,72]))
print('Original Conga Line: ', end = ' ')
printLinkedList(head)
returned_value = conga_line(head)
print(returned_value) #This should print False
unittest.output_test(returned_value, False)
print()
# Out:
# Original Conga Line:  10-->15-->34-->41-->56-->72
#
# True
# Accepted
#
# Original Conga Line:  10-->15-->44-->41-->56-->72
#
# False
# Accepted

# %% [markdown]
# Remove Compartment

# %%
def index_count(head,n):
    a_temp= head
    index=0
    new_index=0
    while a_temp!=None:
        index+=1
        a_temp=a_temp.next
    new_index=index-n

    return new_index
def remove_compartment(head, n):
    b_temp=head
    count=0
    prev_temp=None
    new_temp=head
    while b_temp!=None:
        if count==index_count(head,n) :
            if prev_temp==None:
                new_temp=b_temp.next
            else:
                prev_temp.next=b_temp.next
            break
        prev_temp=b_temp
        b_temp=b_temp.next
        count += 1
    return new_temp

head = createList(np.array([10,15,34,41,56,72]))
print('Original Compartment Sequence: ', end = ' ')
printLinkedList(head)
head = remove_compartment(head,2)
print('Changed Compartment Sequence: ', end = ' ')
printLinkedList(head) #This should print 10-->15-->34-->41-->72
print()

head = createList(np.array([10,15,34,41,56,72]))
print('Original Compartment Sequence: ', end = ' ')
printLinkedList(head)
head = remove_compartment(head,7)
print('Changed Compartment Sequence: ', end = ' ')
printLinkedList(head) #This should print 10-->15-->34-->41-->56-->72
print()

head = createList(np.array([10,15,34,41,56,72]))
print('Original Compartment Sequence: ', end = ' ')
printLinkedList(head)
head = remove_compartment(head,6)
print('Changed Compartment Sequence: ', end = ' ')
printLinkedList(head) #This should print 15-->34-->41-->56-->72
print()
# Out:
# Original Compartment Sequence:  10-->15-->34-->41-->56-->72
#
# Changed Compartment Sequence:  10-->15-->34-->41-->72
#
#
# Original Compartment Sequence:  10-->15-->34-->41-->56-->72
#
# Changed Compartment Sequence:  10-->15-->34-->41-->56-->72
#
#
# Original Compartment Sequence:  10-->15-->34-->41-->56-->72
#
# 15
# Changed Compartment Sequence:  15-->34-->41-->56-->72

# %% [markdown]
# Shuffle on index

# %%
def shuffle_on_index(head):
    temp=head
    if temp==None or temp.next==None:
        return temp
    else:
        even_temp=temp
        odd_temp=temp.next
        even=even_temp
        odd=odd_temp
        while odd!=None and odd.next!=None:
            even.next=odd.next
            even= even.next
            odd.next = even.next
            odd= odd.next
        even.next = odd_temp
        return even_temp
head = createList(np.array(['S','E','N','P','A','I']))
print('Original Play List: ', end = ' ')
printLinkedList(head)
newhead =  shuffle_on_index(head)
print('New Play List: ', end = ' ')
printLinkedList(newhead) #This should print S-->N-->A-->E-->P-->I
print()

head = createList(np.array(['N','I','S','H','I','N','O','Y','A']))
print('Original Play List: ', end = ' ')
printLinkedList(head)
newhead =  shuffle_on_index(head)
print('New Play List: ', end = ' ')
printLinkedList(newhead) #This should print N-->S-->I-->O-->A-->I-->H-->N-->Y
print()
# Out:
# Original Play List:  S-->E-->N-->P-->A-->I
#
# New Play List:  S-->N-->A-->E-->P-->I
#
#
# Original Play List:  N-->I-->S-->H-->I-->N-->O-->Y-->A
#
# New Play List:  N-->S-->I-->O-->A-->I-->H-->N-->Y

# %% [markdown]
# Scavenger hunt

# %%
def find_next_clue(head):
  temp=head
  while temp!=None:
    condition=False
    new_temp=temp.next
    while new_temp!=None:
      if temp.elem<new_temp.elem:
        condition=True
        print(f'{new_temp.elem} is greater than {temp.elem}')
        break
      new_temp=new_temp.next
    if condition==False:
      print(f'No next element greater than {temp.elem}')
    temp=temp.next
head = createList(np.array([7,85,54,16,11,30]))
print('Given Clue List: ', end = ' ')
printLinkedList(head)
find_next_clue(head)
print()

head = createList(np.array([20,13,33,12]))
print('Given Clue List: ', end = ' ')
printLinkedList(head)
find_next_clue(head)
print()
# Out:
# Given Clue List:  7-->85-->54-->16-->11-->30
#
# 85 is greater than 7
# No next element greater than 85
# No next element greater than 54
# 30 is greater than 16
# 30 is greater than 11
# No next element greater than 30
#
# Given Clue List:  20-->13-->33-->12
#
# 33 is greater than 20
# 33 is greater than 13
# No next element greater than 33
# No next element greater than 12

# %% [markdown]
# PRACTICE SHEET

# %%
def move_last_to_front(head):
    if head ==None or head.next==None:
        return head

    # Find the last node and its previous node (if applicable)
    prev_last, last = None, head
    while last.next !=None:
        prev_last = last
        last = last.next

    # Remove the last node from its current position
    prev_last.next = None

    # Move the last node to the front
    last.next = head
    head = last


    return head

# Test cases
# Test case 1
arr1 = [1, 2, 3, 4, 5]
head1 = createList(arr1)
print("Input:", end=" ")
printLinkedList(head1)
head1 = move_last_to_front(head1)
print("Output:", end=" ")
printLinkedList(head1)

# Test case 2
arr2 = [3, 8, 1, 5, 7, 12]
head2 = createList(arr2)
print("Input:", end=" ")
printLinkedList(head2)
head2 = move_last_to_front(head2)
print("Output:", end=" ")
printLinkedList(head2)
# Out:
# Input: 1-->2-->3-->4-->5
#
# Output: 5-->1-->2-->3-->4
#
# Input: 3-->8-->1-->5-->7-->12
#
# Output: 12-->3-->8-->1-->5-->7

# %%
def common(head1,head2):
  common_head=None
  common_tail=None
  while head1!=None and head2!=None:
          if head1.elem==head2.elem:
            new_node = Node(head1.elem)
            if common_head==None:
                common_head = new_node
                common_tail = common_head
            else:
                common_tail.next = new_node
                common_tail = common_tail.next

            head2=head2.next
          head1=head1.next
  return common_head



arr1 = [1,2,3,4,6]
arr2 = [2,3,4]
head1 = createList(arr1)
head2 = createList(arr2)
print("Input:", end=" ")
printLinkedList(head1)
print("Input:", end=" ")
printLinkedList(head2)
head3 = common(head1,head2)
print("Output:", end=" ")
printLinkedList(head3)
# Out:
# Input: 1-->2-->3-->4-->6
#
# Input: 2-->3-->4
#
# Output: 2-->3-->4

# %%
def evenshift(head1):
  temp=head
  while temp!=None:
    if temp.elem%2==0 and temp.next.elem%2==0:
      temp.next=temp
      temp=temp.next
    else:
      pass
    temp=temp.next
  return temp
arr1 = [1,2,3,4,6]
head1 = createList(arr1)
print("Input:", end=" ")
printLinkedList(head1)
head3 = subshift(head1)
print("Output:", end=" ")
printLinkedList(head3)
# Out:
# Input: 1-->2-->3-->4-->6
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-69-914383655757> in <cell line: 15>()
#      13 print("Input:", end=" ")
#      14 printLinkedList(head1)
# ---> 15 head3 = subshift(head1)
#      16 print("Output:", end=" ")
#      17 printLinkedList(head3)
#
# <ipython-input-68-6936d1bbbec5> in subshift(head1)
#       1 def subshift(head1):
#       2   temp=head
# ----> 3   while temp!=None:
#       4     if temp.elem%2==0 and temp.next.elem%2==0:
#       5       temp.next=temp
#
# KeyboardInterrupt:
